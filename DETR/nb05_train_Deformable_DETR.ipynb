# %%
import itertools
import os

import pytorch_lightning as pl
from pytorch_lightning import Trainer
from sklearn.model_selection import KFold
from torch.utils.data import DataLoader, SubsetRandomSampler
from transformers import DeformableDetrConfig, DeformableDetrForObjectDetection

from detr_config import Config
from detr_dataset import collate_fn, get_train_dataset, get_test_dataset
from detr_model import DETRModel
# Out:
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.

# %%
# Dataset

train_dataset = get_train_dataset()
test_dataset = get_test_dataset()
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
# HyperParameters

params_num_queries = [10, 50,100]
params_d_model = [64, 128, 256]
params_encoder_decoder_layers = [2,4,6]

hyperparameters = itertools.product(*[
    params_num_queries,
    params_d_model,
    params_encoder_decoder_layers
])

Config.CHECKPOINT = "SenseTime/deformable-detr"


# Hyperparameter Search

for num_queries, d_model, encoder_decoder_layers in hyperparameters:
    print('(Num Queries, Dim model, Enc-Dec Layers): ', 
            f'({num_queries}, {d_model}, {encoder_decoder_layers})' )

    # Model Construction

    config = DeformableDetrConfig.from_pretrained(
        Config.CHECKPOINT,
        num_labels=1,
        id2label = {0:'Mass'}, 
        label2id={'Mass': 0},
        num_queries = num_queries,
        d_model = d_model,
        num_head = 8,
        encoder_layers = encoder_decoder_layers,
        decoder_layers = encoder_decoder_layers,
        position_embedding_type  = 'sine',
        decoder_ffn_dim = 2048,
        encoder_ffn_dim = 2048,
    )

    detr_model = DeformableDetrForObjectDetection.from_pretrained(
        Config.CHECKPOINT,
        config = config,
        ignore_mismatched_sizes=True
    )

    model = DETRModel(detr_model=detr_model)


    # Training with K-fold Cross Validation 

    k_fold = KFold(n_splits=10, shuffle=True, random_state=123456)

    for fold, (train_idx, valid_idx) in enumerate(k_fold.split(train_dataset)):
        print(f"Fold {fold + 1}")

        train_loader = DataLoader(
            dataset = train_dataset,
            batch_size = Config.BATCH_SIZE,
            collate_fn=collate_fn,
            sampler = SubsetRandomSampler(train_idx),
        )

        valid_loader = DataLoader(
            dataset = train_dataset,
            batch_size = Config.BATCH_SIZE,
            collate_fn=collate_fn,
            sampler = SubsetRandomSampler(valid_idx),
        )

        checkpoint_callback = pl.callbacks.ModelCheckpoint(
            save_top_k = 1,
            save_last = True,
            monitor = "valid_loss",
            mode = "min"
        )

        early_stopping_callback = pl.callbacks.EarlyStopping(
            monitor = 'valid_loss',
            patience = 15
        )

        version = os.path.join(
            'deformable',
            f'queries={num_queries}_dmodel={d_model}_layers={encoder_decoder_layers}',
            f'fold_{fold+1}'
        )

        logger = pl.loggers.TensorBoardLogger(
            save_dir = './',
            version = version
        )

        trainer = Trainer(
            max_epochs = Config.EPOCHS, 
            log_every_n_steps = 5, 
            callbacks = [
                checkpoint_callback, 
                early_stopping_callback
            ],
            accelerator = Config.ACCELERATOR,
            logger = logger
        )
        
        trainer.fit(
            model, 
            train_dataloaders = train_loader, 
            val_dataloaders = valid_loader
        )

        break # Fold
    break # Hyperparameter
# Out:
# (Num Queries, Dim model, Enc-Dec Layers):  (10, 64, 2)
# Some weights of the model checkpoint at SenseTime/deformable-detr were not used when initializing DeformableDetrForObjectDetection: ['model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked', 'model.decoder.layers.3.encoder_attn.value_proj.bias', 'model.decoder.layers.5.self_attn.out_proj.bias', 'model.decoder.layers.4.fc1.weight', 'model.decoder.layers.2.self_attn_layer_norm.bias', 'model.decoder.layers.3.self_attn.out_proj.bias', 'model.decoder.layers.2.final_layer_norm.weight', 'model.decoder.layers.3.self_attn_layer_norm.bias', 'model.encoder.layers.2.self_attn.sampling_offsets.bias', 'model.encoder.layers.4.self_attn.value_proj.weight', 'model.decoder.layers.3.final_layer_norm.weight', 'model.decoder.layers.2.fc2.bias', 'model.decoder.layers.3.encoder_attn_layer_norm.bias', 'model.decoder.layers.5.self_attn.k_proj.bias', 'model.encoder.layers.4.fc2.bias', 'model.decoder.layers.5.fc1.weight', 'model.encoder.layers.4.self_attn_layer_norm.weight', 'model.encoder.layers.3.self_attn.attention_weights.weight', 'model.encoder.layers.3.self_attn_layer_norm.bias', 'model.encoder.layers.5.fc2.bias', 'model.decoder.layers.4.encoder_attn_layer_norm.weight', 'model.decoder.layers.2.encoder_attn.value_proj.weight', 'model.encoder.layers.5.self_attn.attention_weights.bias', 'model.decoder.layers.5.encoder_attn.output_proj.weight', 'model.decoder.layers.2.fc1.bias', 'model.decoder.layers.3.encoder_attn.output_proj.bias', 'model.decoder.layers.5.final_layer_norm.bias', 'model.decoder.layers.5.encoder_attn.value_proj.weight', 'model.decoder.layers.4.self_attn_layer_norm.bias', 'model.decoder.layers.2.fc2.weight', 'model.encoder.layers.5.self_attn.value_proj.weight', 'model.encoder.layers.4.fc1.bias', 'model.encoder.layers.4.self_attn.sampling_offsets.weight', 'model.decoder.layers.5.final_layer_norm.weight', 'model.decoder.layers.4.final_layer_norm.bias', 'model.decoder.layers.3.self_attn.out_proj.weight', 'model.decoder.layers.3.fc1.weight', 'model.decoder.layers.4.encoder_attn_layer_norm.bias', 'model.decoder.layers.4.fc1.bias', 'model.decoder.layers.2.encoder_attn.sampling_offsets.weight', 'model.decoder.layers.2.encoder_attn.attention_weights.weight', 'model.encoder.layers.2.self_attn.attention_weights.bias', 'model.encoder.layers.4.self_attn.output_proj.weight', 'model.decoder.layers.2.encoder_attn.value_proj.bias', 'model.encoder.layers.2.final_layer_norm.bias', 'model.decoder.layers.3.fc2.bias', 'model.decoder.layers.2.encoder_attn.attention_weights.bias', 'model.encoder.layers.5.self_attn_layer_norm.weight', 'model.encoder.layers.2.fc1.bias', 'model.decoder.layers.5.self_attn_layer_norm.weight', 'model.decoder.layers.4.self_attn.k_proj.bias', 'model.decoder.layers.4.self_attn.v_proj.weight', 'model.decoder.layers.2.self_attn.k_proj.weight', 'model.encoder.layers.5.fc2.weight', 'model.decoder.layers.3.self_attn.k_proj.weight', 'model.decoder.layers.2.encoder_attn_layer_norm.bias', 'model.decoder.layers.3.final_layer_norm.bias', 'model.decoder.layers.2.self_attn_layer_norm.weight', 'model.encoder.layers.2.self_attn.attention_weights.weight', 'model.decoder.layers.3.encoder_attn.attention_weights.bias', 'model.encoder.layers.3.self_attn.attention_weights.bias', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.decoder.layers.3.self_attn.v_proj.bias', 'model.encoder.layers.5.final_layer_norm.bias', 'model.encoder.layers.5.self_attn.sampling_offsets.weight', 'model.decoder.layers.5.self_attn.out_proj.weight', 'model.decoder.layers.4.self_attn.out_proj.weight', 'model.decoder.layers.5.encoder_attn.output_proj.bias', 'model.encoder.layers.2.fc2.weight', 'model.decoder.layers.4.self_attn.q_proj.weight', 'model.decoder.layers.2.encoder_attn.sampling_offsets.bias', 'model.encoder.layers.2.self_attn.output_proj.weight', 'model.encoder.layers.5.self_attn.attention_weights.weight', 'model.decoder.layers.2.self_attn.q_proj.bias', 'model.encoder.layers.2.self_attn_layer_norm.weight', 'model. ...
# - This IS expected if you are initializing DeformableDetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DeformableDetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DeformableDetrForObjectDetection were not initialized from the model checkpoint at SenseTime/deformable-detr and are newly initialized because the shapes did not match:
# - bbox_embed.0.layers.0.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - bbox_embed.0.layers.0.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - bbox_embed.0.layers.1.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - bbox_embed.0.layers.1.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - bbox_embed.0.layers.2.weight: found shape torch.Size([4, 256]) in the checkpoint and torch.Size([4, 64]) in the model instantiated
# - class_embed.0.bias: found shape torch.Size([91]) in the checkpoint and torch.Size([1]) in the model instantiated
# - class_embed.0.weight: found shape torch.Size([91, 256]) in the checkpoint and torch.Size([1, 64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn.attention_weights.weight: found shape torch.Size([128, 256]) in the checkpoint and torch.Size([128, 64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn.output_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn.output_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn.sampling_offsets.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([256, 64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn.value_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn.value_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.encoder_attn_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.fc1.bias: found shape torch.Size([1024]) in the checkpoint and torch.Size([2048]) in the model instantiated
# - model.decoder.layers.0.fc1.weight: found shape torch.Size([1024, 256]) in the checkpoint and torch.Size([2048, 64]) in the model instantiated
# - model.decoder.layers.0.fc2.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.fc2.weight: found shape torch.Size([256, 1024]) in the checkpoint and torch.Size([64, 2048]) in the model instantiated
# - model.decoder.layers.0.final_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.final_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.self_attn.k_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.self_attn.k_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.0.self_attn.out_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.self_attn.out_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.0.self_attn.q_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.self_attn.q_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.0.self_attn.v_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.self_attn.v_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.0.self_attn_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.0.self_attn_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn.attention_weights.weight: found shape torch.Size([128, 256]) in the checkpoint and torch.Size([128, 64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn.output_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn.output_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn.sampling_offsets.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([256, 64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn.value_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn.value_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.encoder_attn_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.fc1.bias: found shape torch.Size([1024]) in the checkpoint and torch.Size([2048]) in the model instantiated
# - model.decoder.layers.1.fc1.weight: found shape torch.Size([1024, 256]) in the checkpoint and torch.Size([2048, 64]) in the model instantiated
# - model.decoder.layers.1.fc2.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.fc2.weight: found shape torch.Size([256, 1024]) in the checkpoint and torch.Size([64, 2048]) in the model instantiated
# - model.decoder.layers.1.final_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.final_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.self_attn.k_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.self_attn.k_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.1.self_attn.out_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.self_attn.out_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.1.self_attn.q_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.self_attn.q_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.1.self_attn.v_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.self_attn.v_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.decoder.layers.1.self_attn_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.decoder.layers.1.self_attn_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.0.fc1.bias: found shape torch.Size([1024]) in the checkpoint and torch.Size([2048]) in the model instantiated
# - model.encoder.layers.0.fc1.weight: found shape torch.Size([1024, 256]) in the checkpoint and torch.Size([2048, 64]) in the model instantiated
# - model.encoder.layers.0.fc2.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.0.fc2.weight: found shape torch.Size([256, 1024]) in the checkpoint and torch.Size([64, 2048]) in the model instantiated
# - model.encoder.layers.0.final_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.0.final_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.0.self_attn.attention_weights.weight: found shape torch.Size([128, 256]) in the checkpoint and torch.Size([128, 64]) in the model instantiated
# - model.encoder.layers.0.self_attn.output_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.0.self_attn.output_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.encoder.layers.0.self_attn.sampling_offsets.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([256, 64]) in the model instantiated
# - model.encoder.layers.0.self_attn.value_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.0.self_attn.value_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.encoder.layers.0.self_attn_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.0.self_attn_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.1.fc1.bias: found shape torch.Size([1024]) in the checkpoint and torch.Size([2048]) in the model instantiated
# - model.encoder.layers.1.fc1.weight: found shape torch.Size([1024, 256]) in the checkpoint and torch.Size([2048, 64]) in the model instantiated
# - model.encoder.layers.1.fc2.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.1.fc2.weight: found shape torch.Size([256, 1024]) in the checkpoint and torch.Size([64, 2048]) in the model instantiated
# - model.encoder.layers.1.final_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.1.final_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.1.self_attn.attention_weights.weight: found shape torch.Size([128, 256]) in the checkpoint and torch.Size([128, 64]) in the model instantiated
# - model.encoder.layers.1.self_attn.output_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.1.self_attn.output_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.encoder.layers.1.self_attn.sampling_offsets.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([256, 64]) in the model instantiated
# - model.encoder.layers.1.self_attn.value_proj.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.1.self_attn.value_proj.weight: found shape torch.Size([256, 256]) in the checkpoint and torch.Size([64, 64]) in the model instantiated
# - model.encoder.layers.1.self_attn_layer_norm.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.encoder.layers.1.self_attn_layer_norm.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.0.0.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.0.0.weight: found shape torch.Size([256, 512, 1, 1]) in the checkpoint and torch.Size([64, 512, 1, 1]) in the model instantiated
# - model.input_proj.0.1.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.0.1.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.1.0.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.1.0.weight: found shape torch.Size([256, 1024, 1, 1]) in the checkpoint and torch.Size([64, 1024, 1, 1]) in the model instantiated
# - model.input_proj.1.1.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.1.1.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.2.0.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.2.0.weight: found shape torch.Size([256, 2048, 1, 1]) in the checkpoint and torch.Size([64, 2048, 1, 1]) in the model instantiated
# - model.input_proj.2.1.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.2.1.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.3.0.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.3.0.weight: found shape torch.Size([256, 2048, 3, 3]) in the checkpoint and torch.Size([64, 2048, 3, 3]) in the model instantiated
# - model.input_proj.3.1.bias: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.input_proj.3.1.weight: found shape torch.Size([256]) in the checkpoint and torch.Size([64]) in the model instantiated
# - model.level_embed: found shape torch.Size([4, 256]) in the checkpoint and torch.Size([4, 64]) in the model instantiated
# - model.query_position_embeddings.weight: found shape torch.Size([300, 512]) in the checkpoint and torch.Size([10, 128]) in the model instantiated
# - model.reference_points.weight: found shape torch.Size([2, 256]) in the checkpoint and torch.Size([2, 64]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\utilities\parsing.py:197: UserWarning: Attribute 'detr_model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['detr_model'])`.
#   rank_zero_warn(
# Fold 1
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name       | Type                             | Params
# ----------------------------------------------------------------
# 0 | detr_model | DeformableDetrForObjectDetection | 26.1 M
# ----------------------------------------------------------------
# 25.9 M    Trainable params
# 222 K     Non-trainable params
# 26.1 M    Total params
# 104.399   Total estimated model params size (MB)
# <generator object Module.named_parameters at 0x0000020820448C40>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alejandro Duque\Documents\USFQ\Proyecto Integrador\Workspace\DETR - Implementation\train_Deformable_DETR.ipynb Cell 3 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=86'>87</a>     logger = pl.loggers.TensorBoardLogger(
#      <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=87'>88</a>         save_dir = './',
#      <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=88'>89</a>         version = version
#      <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=89'>90</a>     )
#      <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=91'>92</a>     trainer = Trainer(
#      <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=92'>93</a>         max_epochs = Config.EPOCHS,
#      <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=93'>94</a>         log_every_n_steps = 5,
#    (...)
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=99'>100</a>         logger = logger
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=100'>101</a>     )
# --> <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=102'>103</a>     trainer.fit(
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=103'>104</a>         model,
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=104'>105</a>         train_dataloaders = train_loader,
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=105'>106</a>         val_dataloaders = valid_loader
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=106'>107</a>     )
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=108'>109</a>     break # Fold
#     <a href='vscode-notebook-cell:/c%3A/Users/Alejandro%20Duque/Documents/USFQ/Proyecto%20Integrador/Workspace/DETR%20-%20Implementation/train_Deformable_DETR.ipynb#W1sZmlsZQ%3D%3D?line=109'>110</a> break # Hyperparameter
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\trainer\trainer.py:532, in Trainer.fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     530 self.strategy._lightning_module = model
#     531 _verify_strategy_supports_compile(model, self.strategy)
# --> 532 call._call_and_handle_interrupt(
#     533     self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     534 )
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\trainer\call.py:43, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      41     if trainer.strategy.launcher is not None:
#      42         return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 43     return trainer_fn(*args, **kwargs)
#      45 except _TunerExitException:
#      46     _call_teardown_hook(trainer)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\trainer\trainer.py:571, in Trainer._fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     561 self._data_connector.attach_data(
#     562     model, train_dataloaders=train_dataloaders, val_dataloaders=val_dataloaders, datamodule=datamodule
#     563 )
#     565 ckpt_path = self._checkpoint_connector._select_ckpt_path(
#     566     self.state.fn,
#     567     ckpt_path,
#     568     model_provided=True,
#     569     model_connected=self.lightning_module is not None,
#     570 )
# --> 571 self._run(model, ckpt_path=ckpt_path)
#     573 assert self.state.stopped
#     574 self.training = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\trainer\trainer.py:963, in Trainer._run(self, model, ckpt_path)
#     960     call._call_callback_hooks(self, "on_fit_start")
#     961     call._call_lightning_module_hook(self, "on_fit_start")
# --> 963 _log_hyperparams(self)
#     965 if self.strategy.restore_checkpoint_after_setup:
#     966     log.debug(f"{self.__class__.__name__}: restoring module and callbacks from checkpoint path: {ckpt_path}")
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\loggers\utilities.py:95, in _log_hyperparams(trainer)
#      93     logger.log_hyperparams(hparams_initial)
#      94 logger.log_graph(pl_module)
# ---> 95 logger.save()
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\lightning_utilities\core\rank_zero.py:32, in rank_zero_only.<locals>.wrapped_fn(*args, **kwargs)
#      30     raise RuntimeError("The `rank_zero_only.rank` needs to be set before use")
#      31 if rank == 0:
# ---> 32     return fn(*args, **kwargs)
#      33 return None
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\loggers\tensorboard.py:224, in TensorBoardLogger.save(self)
#     222 # save the metatags file if it doesn't exist and the log directory exists
#     223 if _is_dir(self._fs, dir_path) and not self._fs.isfile(hparams_file):
# --> 224     save_hparams_to_yaml(hparams_file, self.hparams)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\pytorch_lightning\core\saving.py:324, in save_hparams_to_yaml(config_yaml, hparams, use_omegaconf)
#     322 try:
#     323     v = v.name if isinstance(v, Enum) else v
# --> 324     yaml.dump(v)
#     325 except TypeError:
#     326     warn(f"Skipping '{k}' parameter because it is not possible to safely dump to YAML.")
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\__init__.py:253, in dump(data, stream, Dumper, **kwds)
#     248 def dump(data, stream=None, Dumper=Dumper, **kwds):
#     249     """
#     250     Serialize a Python object into a YAML stream.
#     251     If stream is None, return the produced string instead.
#     252     """
# --> 253     return dump_all([data], stream, Dumper=Dumper, **kwds)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\__init__.py:241, in dump_all(documents, stream, Dumper, default_style, default_flow_style, canonical, indent, width, allow_unicode, line_break, encoding, explicit_start, explicit_end, version, tags, sort_keys)
#     239     dumper.open()
#     240     for data in documents:
# --> 241         dumper.represent(data)
#     242     dumper.close()
#     243 finally:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:27, in BaseRepresenter.represent(self, data)
#      26 def represent(self, data):
# ---> 27     node = self.represent_data(data)
#      28     self.serialize(node)
#      29     self.represented_objects = {}
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:52, in BaseRepresenter.represent_data(self, data)
#      50 for data_type in data_types:
#      51     if data_type in self.yaml_multi_representers:
# ---> 52         node = self.yaml_multi_representers[data_type](self, data)
#      53         break
#      54 else:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:342, in Representer.represent_object(self, data)
#     339 function_name = '%s.%s' % (function.__module__, function.__name__)
#     340 if not args and not listitems and not dictitems \
#     341         and isinstance(state, dict) and newobj:
# --> 342     return self.represent_mapping(
#     343             'tag:yaml.org,2002:python/object:'+function_name, state)
#     344 if not listitems and not dictitems  \
#     345         and isinstance(state, dict) and not state:
#     346     return self.represent_sequence(tag+function_name, args)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:118, in BaseRepresenter.represent_mapping(self, tag, mapping, flow_style)
#     116 for item_key, item_value in mapping:
#     117     node_key = self.represent_data(item_key)
# --> 118     node_value = self.represent_data(item_value)
#     119     if not (isinstance(node_key, ScalarNode) and not node_key.style):
#     120         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:364, in Representer.represent_ordered_dict(self, data)
#     361 tag = 'tag:yaml.org,2002:python/object/apply:%s.%s' \
#     362         % (data_type.__module__, data_type.__name__)
#     363 items = [[key, value] for key, value in data.items()]
# --> 364 return self.represent_sequence(tag, [items])
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:199, in SafeRepresenter.represent_list(self, data)
#     191 def represent_list(self, data):
#     192     #pairs = (len(data) > 0 and isinstance(data, list))
#     193     #if pairs:
#    (...)
#     197     #            break
#     198     #if not pairs:
# --> 199         return self.represent_sequence('tag:yaml.org,2002:seq', data)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:199, in SafeRepresenter.represent_list(self, data)
#     191 def represent_list(self, data):
#     192     #pairs = (len(data) > 0 and isinstance(data, list))
#     193     #if pairs:
#    (...)
#     197     #            break
#     198     #if not pairs:
# --> 199         return self.represent_sequence('tag:yaml.org,2002:seq', data)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:52, in BaseRepresenter.represent_data(self, data)
#      50 for data_type in data_types:
#      51     if data_type in self.yaml_multi_representers:
# ---> 52         node = self.yaml_multi_representers[data_type](self, data)
#      53         break
#      54 else:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:342, in Representer.represent_object(self, data)
#     339 function_name = '%s.%s' % (function.__module__, function.__name__)
#     340 if not args and not listitems and not dictitems \
#     341         and isinstance(state, dict) and newobj:
# --> 342     return self.represent_mapping(
#     343             'tag:yaml.org,2002:python/object:'+function_name, state)
#     344 if not listitems and not dictitems  \
#     345         and isinstance(state, dict) and not state:
#     346     return self.represent_sequence(tag+function_name, args)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:118, in BaseRepresenter.represent_mapping(self, tag, mapping, flow_style)
#     116 for item_key, item_value in mapping:
#     117     node_key = self.represent_data(item_key)
# --> 118     node_value = self.represent_data(item_value)
#     119     if not (isinstance(node_key, ScalarNode) and not node_key.style):
#     120         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:364, in Representer.represent_ordered_dict(self, data)
#     361 tag = 'tag:yaml.org,2002:python/object/apply:%s.%s' \
#     362         % (data_type.__module__, data_type.__name__)
#     363 items = [[key, value] for key, value in data.items()]
# --> 364 return self.represent_sequence(tag, [items])
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:199, in SafeRepresenter.represent_list(self, data)
#     191 def represent_list(self, data):
#     192     #pairs = (len(data) > 0 and isinstance(data, list))
#     193     #if pairs:
#    (...)
#     197     #            break
#     198     #if not pairs:
# --> 199         return self.represent_sequence('tag:yaml.org,2002:seq', data)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:199, in SafeRepresenter.represent_list(self, data)
#     191 def represent_list(self, data):
#     192     #pairs = (len(data) > 0 and isinstance(data, list))
#     193     #if pairs:
#    (...)
#     197     #            break
#     198     #if not pairs:
# --> 199         return self.represent_sequence('tag:yaml.org,2002:seq', data)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:52, in BaseRepresenter.represent_data(self, data)
#      50 for data_type in data_types:
#      51     if data_type in self.yaml_multi_representers:
# ---> 52         node = self.yaml_multi_representers[data_type](self, data)
#      53         break
#      54 else:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:342, in Representer.represent_object(self, data)
#     339 function_name = '%s.%s' % (function.__module__, function.__name__)
#     340 if not args and not listitems and not dictitems \
#     341         and isinstance(state, dict) and newobj:
# --> 342     return self.represent_mapping(
#     343             'tag:yaml.org,2002:python/object:'+function_name, state)
#     344 if not listitems and not dictitems  \
#     345         and isinstance(state, dict) and not state:
#     346     return self.represent_sequence(tag+function_name, args)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:118, in BaseRepresenter.represent_mapping(self, tag, mapping, flow_style)
#     116 for item_key, item_value in mapping:
#     117     node_key = self.represent_data(item_key)
# --> 118     node_value = self.represent_data(item_value)
#     119     if not (isinstance(node_key, ScalarNode) and not node_key.style):
#     120         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:364, in Representer.represent_ordered_dict(self, data)
#     361 tag = 'tag:yaml.org,2002:python/object/apply:%s.%s' \
#     362         % (data_type.__module__, data_type.__name__)
#     363 items = [[key, value] for key, value in data.items()]
# --> 364 return self.represent_sequence(tag, [items])
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:199, in SafeRepresenter.represent_list(self, data)
#     191 def represent_list(self, data):
#     192     #pairs = (len(data) > 0 and isinstance(data, list))
#     193     #if pairs:
#    (...)
#     197     #            break
#     198     #if not pairs:
# --> 199         return self.represent_sequence('tag:yaml.org,2002:seq', data)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:48, in BaseRepresenter.represent_data(self, data)
#      46 data_types = type(data).__mro__
#      47 if data_types[0] in self.yaml_representers:
# ---> 48     node = self.yaml_representers[data_types[0]](self, data)
#      49 else:
#      50     for data_type in data_types:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:199, in SafeRepresenter.represent_list(self, data)
#     191 def represent_list(self, data):
#     192     #pairs = (len(data) > 0 and isinstance(data, list))
#     193     #if pairs:
#    (...)
#     197     #            break
#     198     #if not pairs:
# --> 199         return self.represent_sequence('tag:yaml.org,2002:seq', data)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:92, in BaseRepresenter.represent_sequence(self, tag, sequence, flow_style)
#      90 best_style = True
#      91 for item in sequence:
# ---> 92     node_item = self.represent_data(item)
#      93     if not (isinstance(node_item, ScalarNode) and not node_item.style):
#      94         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:52, in BaseRepresenter.represent_data(self, data)
#      50 for data_type in data_types:
#      51     if data_type in self.yaml_multi_representers:
# ---> 52         node = self.yaml_multi_representers[data_type](self, data)
#      53         break
#      54 else:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:342, in Representer.represent_object(self, data)
#     339 function_name = '%s.%s' % (function.__module__, function.__name__)
#     340 if not args and not listitems and not dictitems \
#     341         and isinstance(state, dict) and newobj:
# --> 342     return self.represent_mapping(
#     343             'tag:yaml.org,2002:python/object:'+function_name, state)
#     344 if not listitems and not dictitems  \
#     345         and isinstance(state, dict) and not state:
#     346     return self.represent_sequence(tag+function_name, args)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:118, in BaseRepresenter.represent_mapping(self, tag, mapping, flow_style)
#     116 for item_key, item_value in mapping:
#     117     node_key = self.represent_data(item_key)
# --> 118     node_value = self.represent_data(item_value)
#     119     if not (isinstance(node_key, ScalarNode) and not node_key.style):
#     120         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:52, in BaseRepresenter.represent_data(self, data)
#      50 for data_type in data_types:
#      51     if data_type in self.yaml_multi_representers:
# ---> 52         node = self.yaml_multi_representers[data_type](self, data)
#      53         break
#      54 else:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:342, in Representer.represent_object(self, data)
#     339 function_name = '%s.%s' % (function.__module__, function.__name__)
#     340 if not args and not listitems and not dictitems \
#     341         and isinstance(state, dict) and newobj:
# --> 342     return self.represent_mapping(
#     343             'tag:yaml.org,2002:python/object:'+function_name, state)
#     344 if not listitems and not dictitems  \
#     345         and isinstance(state, dict) and not state:
#     346     return self.represent_sequence(tag+function_name, args)
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:118, in BaseRepresenter.represent_mapping(self, tag, mapping, flow_style)
#     116 for item_key, item_value in mapping:
#     117     node_key = self.represent_data(item_key)
# --> 118     node_value = self.represent_data(item_value)
#     119     if not (isinstance(node_key, ScalarNode) and not node_key.style):
#     120         best_style = False
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:52, in BaseRepresenter.represent_data(self, data)
#      50 for data_type in data_types:
#      51     if data_type in self.yaml_multi_representers:
# ---> 52         node = self.yaml_multi_representers[data_type](self, data)
#      53         break
#      54 else:
#
# File c:\ProgramData\miniconda3\envs\detr-env\Lib\site-packages\yaml\representer.py:330, in Representer.represent_object(self, data)
#     328     listitems = list(listitems)
#     329 if dictitems is not None:
# --> 330     dictitems = dict(dictitems)
#     331 if function.__name__ == '__newobj__':
#     332     function = args[0]
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required
